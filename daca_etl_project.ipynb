# %%
# !pip uninstall tabula
# !pip install tabula-py -y

# %%
import tabula
import pandas as pd

# %%
#import tabula 
#dfs = tabula.read_pdf("DACA_Population_Receipts_since_Injunction_Jun_30_2020.pdf", pages ='all')

# %%
#from tabula import read_pdf 
df = read_pdf('./DACA_Population_Receipts_since_Injunction_Jun_30_2020.pdf')
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
df1 = read_pdf('Quarterly_All_Forms_FY2020Q3.pdf')
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
#from tabula import wrapper
#dfs = wrapper.read_pdf("DACA_Population_Receipts_since_Injunction_Jun_30_2020.pdf",multiple_tables=True)

# %%
dfl = df[0].iloc[3:]
dfl1 = df1[0].iloc[3:]

# %%
for i, x in dfl.iterrows():
    print(x)
# Out:
# Approximate Active DACA Recipients:    Jul-20 4,760 1,560
# Name: 3, dtype: object
# Approximate Active DACA Recipients:    Aug-20 10,340 2,360
# Name: 4, dtype: object
# Approximate Active DACA Recipients:    Sep-20 16,990 2,830
# Name: 5, dtype: object
# Approximate Active DACA Recipients:    Oct-20 18,570 2,490
# Name: 6, dtype: object
# Approximate Active DACA Recipients:    Nov-20 25,200 2,540
# Name: 7, dtype: object
# Approximate Active DACA Recipients:    Dec-20 23,650 4,480
# Name: 8, dtype: object
# Approximate Active DACA Recipients:    Jan-21 33,610 3,230
# Name: 9, dtype: object
# Approximate Active DACA Recipients:    Feb-21 30,380 1,890
# Name: 10, dtype: object
# Approximate Active DACA Recipients:    Mar-21 33,960 1,720
# Name: 11, dtype: object
# Approximate Active DACA Recipients:    Apr-21 38,460 1,410
# Name: 12, dtype: object
# Approximate Active DACA Recipients:    May-21 31,020 900
# Name: 13, dtype: object
# ...

# %%
dfl
# Out:
#    Approximate Active DACA Recipients:
# 3                   Jul-20 4,760 1,560
# 4                  Aug-20 10,340 2,360
# 5                  Sep-20 16,990 2,830
# 6                  Oct-20 18,570 2,490
# 7                  Nov-20 25,200 2,540
# 8                  Dec-20 23,650 4,480
# 9                  Jan-21 33,610 3,230
# 10                 Feb-21 30,380 1,890
# 11                 Mar-21 33,960 1,720
# 12                 Apr-21 38,460 1,410
# 13                   May-21 31,020 900
# 14                   Jun-21 27,250 530
# 15                   Jul-21 36,680 500
# 16                   Aug-21 29,850 280
# 17                   Sep-21 36,190 270
# 18                   Oct-21 30,700 260
# 19                   Nov-21 17,700 120
# 20                   Dec-21 22,370 120
# 21                    Jan-22 23,100 80
# 22                    Feb-22 22,830 50
# 23                    Mar-22 18,890 40
# 24                    Apr-22 35,150 60
# 25                    May-22 42,420 70
# ...

# %%
l = []
for i, x in dfl.iterrows():
    j = list(x)[0].split(" ")
    l.append(j)
    print(j)
# Out:
# ['Jul-20', '4,760', '1,560']
# ['Aug-20', '10,340', '2,360']
# ['Sep-20', '16,990', '2,830']
# ['Oct-20', '18,570', '2,490']
# ['Nov-20', '25,200', '2,540']
# ['Dec-20', '23,650', '4,480']
# ['Jan-21', '33,610', '3,230']
# ['Feb-21', '30,380', '1,890']
# ['Mar-21', '33,960', '1,720']
# ['Apr-21', '38,460', '1,410']
# ['May-21', '31,020', '900']
# ['Jun-21', '27,250', '530']
# ['Jul-21', '36,680', '500']
# ['Aug-21', '29,850', '280']
# ['Sep-21', '36,190', '270']
# ['Oct-21', '30,700', '260']
# ['Nov-21', '17,700', '120']
# ['Dec-21', '22,370', '120']
# ['Jan-22', '23,100', '80']
# ['Feb-22', '22,830', '50']
# ['Mar-22', '18,890', '40']
# ['Apr-22', '35,150', '60']
# ['May-22', '42,420', '70']
# ['Jun-22', '35,560', '70']
# ['Grand', 'Total', '645,610', '27,850']

# %%
df2 = pd.DataFrame(l, columns=["Date","Number","Renew","A"])
df2
# Out:
#       Date  Number    Renew       A
# 0   Jul-20   4,760    1,560    None
# 1   Aug-20  10,340    2,360    None
# 2   Sep-20  16,990    2,830    None
# 3   Oct-20  18,570    2,490    None
# 4   Nov-20  25,200    2,540    None
# 5   Dec-20  23,650    4,480    None
# 6   Jan-21  33,610    3,230    None
# 7   Feb-21  30,380    1,890    None
# 8   Mar-21  33,960    1,720    None
# 9   Apr-21  38,460    1,410    None
# 10  May-21  31,020      900    None
# 11  Jun-21  27,250      530    None
# 12  Jul-21  36,680      500    None
# 13  Aug-21  29,850      280    None
# 14  Sep-21  36,190      270    None
# 15  Oct-21  30,700      260    None
# 16  Nov-21  17,700      120    None
# 17  Dec-21  22,370      120    None
# 18  Jan-22  23,100       80    None
# 19  Feb-22  22,830       50    None
# 20  Mar-22  18,890       40    None
# 21  Apr-22  35,150       60    None
# 22  May-22  42,420       70    None
# 23  Jun-22  35,560       70    None
# 24   Grand   Total  645,610  27,850

# %%
#dfs = tabula.read_pdf("DACA_Population_Receipts_since_Injunction_Jun_30_2020.pdf", pages ='all')

# %%
#from tabula import wrapper
#df = wrapper.read_pdf('DACA_Population_Receipts_since_Injunction_Jun_30_2020.pdf',multiple_tables=True)

# %%
#dfs

# %%
for i, x in dfl1.iterrows():
    print(x)
# Out:
# Number of Service-wide Forms Fiscal Year To- Date\rBy Quarter and Form Status\rFiscal Year 2020    NaN
# Unnamed: 0                                                                                         NaN
# Unnamed: 1                                                                                         NaN
# Unnamed: 2                                                                                         NaN
# Unnamed: 3                                                                                         NaN
# Unnamed: 4                                                                                         NaN
# Unnamed: 5                                                                                         NaN
# Unnamed: 6                                                                                         NaN
# Unnamed: 7                                                                                         NaN
# ...

# %%
dfl1
# Out:
#    Number of Service-wide Forms Fiscal Year To- Date\rBy Quarter and Form Status\rFiscal Year 2020  \
# 3                                                 NaN
# 4                                   TOTAL - ALL FORMS
# 5                                                 NaN
# 6                                        Family Based
# 7   I-129F\rI-130\rI-485\rI-600 1\rI-601A\rI-751\r...
# ..                                                ...
# 61                                                NaN
# 62                                                NaN
# 63                            Supplemental Processing
# 64                       DS-230 (IV)\rEOIR Adjustment
# 65                                    EOIR Adjustment
#
#                       Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 3                            NaN        NaN        NaN        NaN        NaN
# 4                      1,926,497  1,643,922    256,151  5,759,297  1,904,468
# ...

# %%
dfl1 = pd.DataFrame(l, columns=["Description","Forms Received 1st Qrt", "Approved 1st Qrt","Denied 1st Qrt","Pending 1st Qrt","Forms Received 2nd Qrt", "Approved 2nd Qrt", "Denied 2nd Qrt","Pending 2nd Qrt","Forms Received 3rd Qrt","Approved 3rd Qrt","Denied 3rd Qrt","Pending 3rd Qrt","Forms Received 4th Qrt", "Approved 4th Qrt","Denied 4th Qrt","Pending 4th Qrt" "Fisc Yr 2020 YTD Forms Received","Fisc Yr 2020 YTD Approved"])Forms Received Approved Denied Pending
dfl1
# Out:
#   File "<ipython-input-160-a4d7e0f59b37>", line 1
#     dfl1 = pd.DataFrame(l, columns=["Description","Forms Received 1st Qrt", "Approved 1st Qrt","Denied 1st Qrt","Pending 1st Qrt","Forms Received 2nd Qrt", "Approved 2nd Qrt", "Denied 2nd Qrt","Pending 2nd Qrt","Forms Received 3rd Qrt","Approved 3rd Qrt","Denied 3rd Qrt","Pending 3rd Qrt","Forms Received 4th Qrt", "Approved 4th Qrt","Denied 4th Qrt","Pending 4th Qrt" "Fisc Yr 2020 YTD Forms Received","Fisc Yr 2020 YTD Approved"])Forms Received Approved Denied Pending
#                                                                                                                                                                                                                                                                                                                                                                                                                                                  ^
# SyntaxError: invalid syntax

# %%
dfl1_new = dfl1.copy()
dfl1_new = dfl1_new.dropna(axis="rows", thresh=10)
dfl1_new.reset_index(drop=True, inplace=True)
dfl1_new
# Out:
#    Number of Service-wide Forms Fiscal Year To- Date\rBy Quarter and Form Status\rFiscal Year 2020  \
# 0                                   TOTAL - ALL FORMS
# 1   I-129F\rI-130\rI-485\rI-600 1\rI-601A\rI-751\r...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   I-129\rI-140\rI-485\rI-526\rI-765 3\rI-829\rI-...
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# ...

# %%
dfl1_new.iloc[41, 0].split("\r")
# Out:
# ['I-90',
#  'I-102',
#  'I-131',
#  'I-131',
#  'I-131',
#  'I-193',
#  'I-360',
#  'I-485',
#  'I-539',
#  'I-824',
#  'Waivers 13',
#  'I-290B']

# %%
df4 = pd.DataFrame(l, columns=["Date","Number","Renew"])
df4

# %%
#dfls = dfs[0].iloc[3:-1]

# %%
#dfl2 = dfs[-2].iloc[4:-1]

# %%
#dfl2

# %%
#dfls

# %%
l = []
for i, x in dfl1.iterrows():
    #j = list(x)[0].split(" ")
    #l.append(j)
    #print(j)

# %%
#from tabula import wrapper
#df = wrapper.read_pdf("sample.pdf",multiple_tables=True)

# %%
#extract multiple tables from a document
#df = read_pdf(file_path, multiple_tables=True)

# %%
# Read pdf into a list of DataFrame
#dfs = tabula.read_pdf("test.pdf", pages='all')

# %%
# Read remote pdf into a list of DataFrame
#dfs2 = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf")

# %%
# convert PDF into CSV
#tabula.convert_into("test.pdf", "output.csv", output_format="csv", pages='all')

# %%
# convert all PDFs in a directory
#tabula.convert_into_by_batch("input_directory", output_format='csv', pages='all')
